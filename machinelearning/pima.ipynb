# %% [markdown]
# ## UCI Pima Indians Diabetes Data, Classification Task
#
# http://archive.ics.uci.edu/ml/datasets/Pima+Indians+Diabetes

# %%
# %matplotlib inline

import numpy as np
import seaborn as sns
sns.axes_style('whitegrid')

from sklearn.ensemble import RandomForestClassifier
from pima import Pima

# %%
seed = np.random.randint(2**16)
print "seed: {}".format(seed)

estimator = RandomForestClassifier(max_features=0.3, min_samples_split=2, n_estimators=32, 
                                   max_depth=3, min_samples_leaf=1, random_state=seed)

pima = Pima(estimator)
pima.train()
pima.experience_curve().show()
pima.plot_roc_curve().show()
# Out:
# seed: 55768
#               precision    recall  f1-score   support
#
# Not Diabetic       0.84      0.93      0.89       105
#     Diabetic       0.77      0.56      0.65        41
#
#  avg / total       0.82      0.83      0.82       146
#
# roc: 0.849477351916
# roc: 0.837094347733
